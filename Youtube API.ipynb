# %% [markdown]
# Setup Youtube Data API - https://console.developers.google.com/
# - Follow this video:
# https://www.youtube.com/watch?v=-QMg39gK624

# %% [markdown]
# To install the required package with conda run:<br>
# conda install -c conda-forge google-api-python-client<br>
# https://anaconda.org/conda-forge/google-api-python-client
# Leran about how to scrape using API they have example codes
# https://developers.google.com/youtube/v3/docs/videos/list#parameters

# %%
api_key="AIzaSyAUaDPX6QT1ioVTGan3NY0OBhKgVOSwZ-4"
#DO NOT USE THIS KEY , GET YOUR OWN USING YOUR GMAIL ACCOUNT

# %%
from apiclient.discovery import build

# %%
#Mention the API name and version
youtube= build('youtube','v3',developerKey=api_key)

# %%
type(youtube)
# Out:
# googleapiclient.discovery.Resource

# %% [markdown]
# Search Youtube Data API

# %% [markdown]
# - Region taken is US by default if not specified
# - can do only list operations with search
# - q=stands for query
# - type= can be a video, channel or playlist
# - Maximum results can only be 50, default is 5

# %%
#create a HTTP request
req=youtube.search().list(q='Avengers',type='video',part='snippet', maxResults=50)

# %%
type(req)
# Out:
# googleapiclient.http.HttpRequest

# %%
res=req.execute()

# %%
len(res['items'])
# Out:
# 50

# %%
for item in res['items']:
    print(item['snippet']['title'])
# Out:
# THE AVENGERS&#39; PICKUP LINES
# Thor vs Hulk - Fight Scene - The Avengers (2012) Movie Clip HD
# Hanging With The AVENGERS and How to Become Black Panther CKN
# Film Theory: The Dark Avengers Are Coming! (Marvel Phase 4 &amp; Black Widow)
# The Avengers - &quot;I&#39;m Always Angry&quot; - Hulk SMASH Scene - Movie CLIP HD
# Action Movies 2020 Full Movie English | Avengers Endgame FULL MOVIE, Best Action Movies HD
# Avengers 5 Marvel Phase 4 Movies News Breakdown - Marvel Easter Eggs
# Hero Kidz: Thanos Iron Gauntlet vs Kids with Nerf Blasters - Avengers Pretend Play
# Avengers  Vs Thanos - Fight Scene - Thor Kills Thanos | AVENGERS 4 ENDGAME (2019) Movie CLIP 4K
# Avengers 4 Endgame Final Battle Full | Avengers: Endgame (2019) - Final Battle [4K]
# avengers cast roast each other | part 2
# Mean Tweets – Avengers Edition
# The Avengers: kids Avenger Commercial
# WHO IS THE STRONGEST AVENGER ?
# Avengers Assemble \Portal Full Scene | Avengers Endgame [ HD ]
# ...

# %%
#create a HTTP request
req=youtube.search().list(q='ESPN',type='channel',part='snippet', maxResults=50)
res=req.execute()

# %%
for item in res['items']:
    print(item['snippet']['title'])
# Out:
# ESPN
# ESPN FC
# ESPN MMA
# NBA on ESPN
# ESPN UK
# ESPN Archive
# ESPN Esports
# ESPN College Football
# ESPN Deportes
# ESPN Shows
# 97.3 ESPN
# ESPN Brasil
# 101 ESPN The Pride of St. Louis Sports
# ESPN Adam Schefter
# ESPN FC
# ESPN
# Skip and Shannon: UNDISPUTED
# 104.5 ESPN
# NBA on TNT
# ESPNcricinfo
# ESPN SC
# ESPN DeportesDallas
# ESPN Fans
# ESPN 700 Sports
# First Take ESPN
# ESPN FÚTBOL PICANTE
# Mike Wilbon on ESPN
# espn derportes
# ESPN
# Aguas Arriba ESPN
# Ahora o Nunca ESPN
# ESPN Events
# ESPN History
# ESPN Honolulu
# ESPN Plus
# ESPN 1420
# ESPN DEPORTES
# SimplementeFútbol Espn
# Duetto ESPN
# Highly Questionable on ESPN
# The NBA on ESPN
# ESPN CHANNEL
# ESPN RONN
# Now Or Never ESPN
# One Sports
# ESPN Australia
# Action Sports Jax on ESPN690AM and on CBS47/FOX30
# ESPN Marketing
# ESPN Tallahassee
# Espn Jr Music

# %%
from datetime import datetime
#1970-01-01T00:00:00Z
start_time=datetime(year=2018,month=1,day=1).strftime('%Y-%m-%dT%H:%M:%SZ')
end_time=datetime(year=2018,month=5,day=1).strftime('%Y-%m-%dT%H:%M:%SZ')

# %%
print(start_time,' ',end_time)
# Out:
# 2018-01-01T00:00:00Z   2018-05-01T00:00:00Z

# %%
#create a HTTP request
req=youtube.search().list(q='ESPN',
                          type='channel',
                          part='snippet', 
                          maxResults=50,
                          publishedBefore=start_time,
                          publishedAfter=end_time)
res=req.execute()

# %%
res
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': '"nxOHAKTVB7baOKsQgTtJIyGxcs8/g87S-WOkJJt5-VH0I6WIEtPtI-8"',
#  'nextPageToken': 'CDIQAA',
#  'regionCode': 'US',
#  'pageInfo': {'totalResults': 175790, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': '"nxOHAKTVB7baOKsQgTtJIyGxcs8/Y9ERx4VHTwW5OReVEsCcKltoS1k"',
#    'id': {'kind': 'youtube#channel', 'channelId': 'UCiWLfSweyRNmLpgEHekhoAg'},
#    'snippet': {'publishedAt': '2005-10-31T23:34:22.000Z',
#     'channelId': 'UCiWLfSweyRNmLpgEHekhoAg',
#     'title': 'ESPN',
#     'description': 'ESPN on YouTube features up-to-the-minute sports news coverage, scores, highlights and commentary for NFL, NHL, MLB, NBA, College Football, NCAA ...',
#     'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/-yOoKXdob9y8/AAAAAAAAAAI/AAAAAAAAAAA/O9ATiv9wGJ0/s88-c-k-no-mo-rj-c0xffffff/photo.jpg'},
# ...

# %%
 request = youtube.videos().list(
        part="snippet,contentDetails,statistics",
        id="Ks-_Mh1QhMc"
    )
response = request.execute()

print(response)
# Out:
# {'kind': 'youtube#videoListResponse', 'etag': '"nxOHAKTVB7baOKsQgTtJIyGxcs8/Tos8Mep3d9GIxDsYWEu0fURKGpw"', 'pageInfo': {'totalResults': 1, 'resultsPerPage': 1}, 'items': [{'kind': 'youtube#video', 'etag': '"nxOHAKTVB7baOKsQgTtJIyGxcs8/uPe_U8nTvRLnjYSsXl4BD-ZXH1U"', 'id': 'Ks-_Mh1QhMc', 'snippet': {'publishedAt': '2012-10-01T15:27:35.000Z', 'channelId': 'UCAuUUnT6oDeKwE6v1NGQxug', 'title': 'Your body language may shape who you are | Amy Cuddy', 'description': 'Body language affects how others see us, but it may also change how we see ourselves. Social psychologist Amy Cuddy argues that "power posing" -- standing in a posture of confidence, even when we don\'t feel confident -- can boost feelings of confidence, and might have an impact on our chances for success. (Note: Some of the findings presented in this talk have been referenced in an ongoing debate among social scientists about robustness and reproducibility. Read Amy Cuddy\'s response here: http://ideas.ted.com/inside-the-debate
# ...

# %% [markdown]
# How to get Video stats like like count, view count etc.

# %%
#response['statistics']
for item in response['items']:
    print(item['statistics'])
# Out:
# {'viewCount': '17929424', 'likeCount': '253702', 'dislikeCount': '5001', 'favoriteCount': '0', 'commentCount': '8027'}

# %% [markdown]
# #### list (most popular videos)
# Code symbol that, when clicked, opens the fullscreen APIs Explorer widget and populates it with values for the 'list (most popular videos)' example for the videos.list method.
# Retrieves a list of YouTube's most popular videos
# The regionCodeparameter identifies the country for which you are retrieving videos. The sample code is set to default to return the most popular videos in the United States. You could also use the videoCategoryId parameter to retrieve the most popular videos in a particular category<br>
# https://developers.google.com/youtube/v3/docs/videos/list

# %%
req= youtube.videos().list(
                            part="snippet,contentDetails,statistics",
                            chart="mostPopular",
                            regionCode="US",
                            maxResults=50
                           )

# %%
res =req.execute()
# Out:
# 5

# %%
len(res['items'])
# Out:
# 50

# %%
for item in res['items']:
    print(item['snippet']['title'])
# Out:
# Post Malone x Nirvana Tribute - Livestream
# Juice WRLD - Righteous (Official Video)
# Fed announces rule changes for personal bank accounts
# THE SCOTTS, Travis Scott, Kid Cudi - THE SCOTTS (FORTNITE ASTRONOMICAL EVENT)
# Bout My Business (feat. Sherhonda Gaulden)
# Lil Baby - All In (Official Video)
# Diamonds
# Fortnite and Travis Scott: Astronomical Trailer
# THE LAST DANCE - Prom Knight Episode 4 - Merrell Twins
# Close out your day in the best way possible...with virtual fireworks! | #DisneyMagicMoments
# Lil Pump & Anuel AA - "ILLUMINATI" (Official Music Video)
# FULL Fortnite x Travis Scott Astronomical Concert
# New COVID-19 study Confirms: "Beating up Asians does NOT prevent Coronavirus"
# The Competition Begins - Instant Influencer
# Picks 1-5: Back-to-Back-to-Back Former Teammates, & Multiple QB's | 2020 NFL Draft
# Fivio Foreign - Drive By (Official Video)
# Round 2 EVERY Pick & Analysis: Eagles Take a QB? | 2020 NFL Draft
# ...

# %%
list_c=[]
for item in res['items']:
    list_c.append(item['snippet']['channelId'])

# %%
import pandas as pd
pd.DataFrame(list_c)[0].unique
# Out:
# <bound method Series.unique of 0     UCeLHszkByNZtPKcaVXOCOQQ
# 1     UC0BletW9phE4xHFM44q4qKA
# 2     UCCXoCcu9Rp7NPbTzIvogpZg
# 3     UClRx3MMyYUyqOxyEqA5F2nQ
# 4     UCR28YDxjDE3ogQROaNdnRbQ
# 5     UCM1gEqLPsgej7ZKzu9w8v7A
# 6     UCR28YDxjDE3ogQROaNdnRbQ
# 7     UClG8odDC8TS6Zpqk9CGVQiQ
# 8     UCwtnkRZcvL4bfopzJ-Von8Q
# 9     UC1xwwLwm6WSMbUn_Tp597hQ
# 10    UC6pjHMC4QXMi4llCCjtDXWg
# 11    UCKy1dAqELo0zrOtPkf0eTMw
# 12    UCSAUGyc_xA8uYzaIVG6MESQ
# 13    UCucot-Zp428OwkyRm2I7v2Q
# 14    UCDVYQ4Zhbm3S2dlz7P1GBDg
# 15    UCm7gu9KfQ6oAg0Z1halgEnA
# 16    UCDVYQ4Zhbm3S2dlz7P1GBDg
# 17    UCV6KDgJskWaEckne5aPA0aQ
# 18    UCsvSj8bT4xqQecl_5nh_cwQ
# 19    UCxcTeAKWJca6XyJ37_ZoKIQ
# 20    UCxcTeAKWJca6XyJ37_ZoKIQ
# 21    UC8Su5vZCXWRag13H53zWVwA
# 22    UC3VlRtY0ARsTRR5Eq8QE1Yg
# 23    UCwNqHDsnBCKT-olwJwIFyfg
# 24    UCDVYQ4Zhbm3S2dlz7P1GBDg
# 25    UC9k23HZ1xMiqxf4gFfmxr5w
# 26    UCDGmojLIoWpXok597xYo8cg
# 27    UCUebubwSuTHfHjWJI4gCS9A
# 28    UCJeH7gl6PbDVV4DTldIOPOA
# ...

# %% [markdown]
# Retrieving data from Channels

# %%
us_videos=pd.read_csv('USvideos.csv')
us_videos.head()
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id              publish_time  \
# 0           22  2017-11-13T17:13:01.000Z
# 1           24  2017-11-13T07:30:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-13T11:00:04.000Z
# 4           24  2017-11-12T18:01:41.000Z
#
# ...

# %%
type(us_videos)
# Out:
# pandas.core.frame.DataFrame

# %%
f=us_videos.video_id.unique()
resp_pd=[]

# %%
for i in range(0,len(f)):
    request = youtube.videos().list(
            part="snippet,contentDetails,statistics",
            id=f[i]
        )
    response= request.execute()
    resp_pd.append(response)
    #print(response)
# Out:
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# <ipython-input-174-57bea05f572f> in <module>
#       4             id=f[i]
#       5         )
# ----> 6     response= request.execute()
#       7     resp_pd.append(response)
#       8     #print(response)
#
# ~\Anaconda3\lib\site-packages\googleapiclient\_helpers.py in positional_wrapper(*args, **kwargs)
#     132                 elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     133                     logger.warning(message)
# --> 134             return wrapped(*args, **kwargs)
#     135
#     136         return positional_wrapper
#
# ~\Anaconda3\lib\site-packages\googleapiclient\http.py in execute(self, http, num_retries)
#     905             callback(resp)
#     906         if resp.status >= 300:
# --> 907             raise HttpError(resp, content, uri=self.uri)
# ...

# %%
len(resp_pd)#['snippet']
#for item in resp_pd:
    #list_c.append(item['snippet']['channelId'])
# Out:
# 994

# %% [markdown]
# Well I reached my daily limit :(, it will refresh at midnight
